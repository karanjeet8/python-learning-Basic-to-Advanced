# %%
#Day2 \\ variable and operator

# %%
A=1
print (A)
# Out:
# 1

# %%
A=2
B=2.4
print (A,B)
# Out:
# 2 2.4

# %%
x="apple"
print (x)
# Out:
# apple

# %%
x= " code in python"
print ("x")
# Out:
# x

# %%
_x ="apple"
print (_x)
# Out:
# apple

# %%
#multivalue variable in python//
x,y,z = "apple","mango", "cherry"
print (x,y,z)
# Out:
# apple mango cherry

# %%
x=y=z = "code with tech branch"
print (x)
print (y)
print(z)
# Out:
# code with tech branch
# code with tech branch
# code with tech branch

# %% [markdown]
# output in python

# %%
x= "coding"
y= "is"
z="easy"
print(x,y,z)
print()
print(x)
print(y)
print(z)
# Out:
# coding is easy
#
# coding
# is
# easy

# %% [markdown]
# #Data type in python

# %%
x=2
print(x)
print (type (x))
# Out:
# 2
# <class 'int'>

# %%
x=2.0
print(x)
print (type (x))
# Out:
# 2.0
# <class 'float'>

# %%
x="karan"
print(x)
print (type (x))
# Out:
# karan
# <class 'str'>

# %%
x=2+1j
print(x)
print (type (x))
# Out:
# (2+1j)
# <class 'complex'>

# %%
x=[1,2,3,4,5]
print(x)
print (type (x))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
x=(1,2,3,4,5)
print(x)
print (type (x))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
# %whos
# Out:
# Variable               Type        Data/Info
# --------------------------------------------
# A                      int         2
# B                      float       2.4
# a                      int         1
# dataframe_columns      function    <function dataframe_colum<...>ns at 0x0000017030B2B270>
# dataframe_hash         function    <function dataframe_hash at 0x0000017030B2B740>
# dtypes_str             function    <function dtypes_str at 0x0000017030B2B7F0>
# get_dataframes         function    <function get_dataframes at 0x000001702DF4F1C0>
# getpass                module      <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module      <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function    <function import_pandas_s<...>ly at 0x0000017030B2B530>
# is_data_frame          function    <function is_data_frame at 0x0000017030B2B110>
# ...

# %%
#Operator in python


x=2
y=3
print(x+y)
print (type (x))
# Out:
# 5
# <class 'int'>

# %%
x=2
y=3.2
print(x+y)
# Out:
# 5.2

# %%
x="karan"
y="jeet"
print(x+ " "+y)
# Out:
# karan jeet

# %%
x=2
y=3
print(x-y)
# Out:
# -1

# %%
x=2
y=3
print(x%y)
# Out:
# 2

# %%
x=2
y=3
print(x/y)
# Out:
# 0.6666666666666666

# %%
x=2
y=3
print(x*y)
# Out:
# 6

# %%
x=255566666678

print(x**44)
# Out:
# ...

# %%
a=((2222+44556)-(345566)*(22345)+(3444**444))
print (a)
# Out:
# ...
